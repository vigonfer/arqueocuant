# %% [markdown]
# <a href="https://colab.research.google.com/github/vigonfer/arqueocuant/blob/master/R_Script_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Reporte de análisis R escrito en Google Colab
#
# Víctor González Fernández
# 2023

# %%
plot(cars)
# Out:
# plot without title

# %% [markdown]
# Este es un gráfico de dispersión.

# %%
hist(cars$dist)
# Out:
# Plot with title “Histogram of cars$dist”

# %% [markdown]
# Este es un Histograma
